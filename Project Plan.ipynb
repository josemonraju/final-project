# %% [markdown]
# https://www.redfin.com/blog/data-center/
#
# Import data from redfin on housing alse prices in somerville
# data frame
# shape
# info
# describe
#
# stored in repository https://github.com/josemonraju/final-project

# %%
import pandas as pd
#redfin=pd.read_csv('redfinweekly.tsv', sep='\t', header=0)
redfin=pd.read_csv('fulldata.csv', header=0)

# https://docs.google.com/spreadsheets/d/1YNT5VfZTwSnUK7nqGAPGZUqOVBbsIC_M1vTgYCCLtVg/edit#gid=635767466  # data descriptions

# %%
redfin.head()
# Out:
#                        Region Month of Period End    Property Type  \
# 0  Los Angeles, CA metro area          April 2019  All Residential
# 1  Los Angeles, CA metro area        October 2019  All Residential
# 2   Washington, DC metro area       February 2012  All Residential
# 3   Washington, DC metro area           July 2014  All Residential
# 4   Washington, DC metro area       February 2015  All Residential
#
#   Region Type  Seasonally Adjusted State Code City          last_updated  \
# 0       Metro                False         CA  NaN  6/14/2020 3:16:51 PM
# 1       Metro                False         CA  NaN  6/14/2020 3:16:51 PM
# 2       Metro                False         DC  NaN  6/14/2020 3:16:51 PM
# 3       Metro                False         DC  NaN  6/14/2020 3:16:51 PM
# 4       Metro                False         DC  NaN  6/14/2020 3:16:51 PM
#
#    Measure Display parent_metro_region  ... pending_sales_yoy Period Duration  \
# ...

# %%
redfin.shape
# Out:
# (700, 65)

# %%
redfin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 65 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Region                          700 non-null    object
#  1   Month of Period End             700 non-null    object
#  2   Property Type                   700 non-null    object
#  3   Region Type                     700 non-null    object
#  4   Seasonally Adjusted             700 non-null    bool
#  5   State Code                      700 non-null    object
#  6   City                            100 non-null    object
#  7   last_updated                    700 non-null    object
#  8   Measure Display                 0 non-null      float64
#  9   parent_metro_region             600 non-null    object
#  10  Period Begin                    700 non-null    object
#  11  Period End                      700 non-null    object
# ...

# %%
redfin.describe()
#
# Out:
#        Measure Display      Table Id  active_listings  active_listings_mom  \
# count              0.0    700.000000     7.000000e+02           700.000000
# mean               NaN  27489.142857     3.464947e+05            -0.000318
# std                NaN  15730.154156     8.039724e+05             0.083291
# min                NaN   1400.000000     5.183000e+03            -0.317038
# 25%                NaN  14454.000000     1.311475e+04            -0.038121
# 50%                NaN  31084.000000     2.143400e+04             0.001327
# 75%                NaN  42644.000000     3.761150e+04             0.041881
# max                NaN  47894.000000     2.726266e+06             0.311180
#
#        active_listings_yoy  Avg Sale To List     Homes Sold     Inventory  \
# count           700.000000        700.000000     700.000000  7.000000e+02
# mean             -0.048132          0.983165   73448.505714  2.596844e+05
# ...

# %%
c
# Out:
#                     Region Month of Period End    Property Type Region Type  \
# 10   Boston, MA metro area          April 2014  All Residential       Metro
# 11   Boston, MA metro area          April 2016  All Residential       Metro
# 12   Boston, MA metro area           June 2016  All Residential       Metro
# 13   Boston, MA metro area           July 2016  All Residential       Metro
# 14   Boston, MA metro area           June 2017  All Residential       Metro
# ..                     ...                 ...              ...         ...
# 660  Boston, MA metro area          April 2019  All Residential       Metro
# 667  Boston, MA metro area       December 2014  All Residential       Metro
# 679  Boston, MA metro area       February 2015  All Residential       Metro
# 680  Boston, MA metro area           July 2015  All Residential       Metro
# 690  Boston, MA metro area      September 2017  All Residential       Metro
#
# ...

# %%
s=redfin[redfin['State Code'==MA], ]

# %% [markdown]
# Option #2
# https://www.kaggle.com/zynicide/wine-reviews/data

# %%
wine=pd.read_csv('wine.csv', header=0)

# %%
wine.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %% [markdown]
# df.loc[['a'], ['b']] = df.loc[['a'], ['b']].applymap(lambda x: ['one', 'two', 'three'])
